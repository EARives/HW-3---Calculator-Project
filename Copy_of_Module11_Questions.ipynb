# %% [markdown]
# <a href="https://colab.research.google.com/github/EARives/HW-3---Calculator-Project/blob/master/Copy_of_Module11_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy.spatial import distance
import warnings
warnings.filterwarnings('ignore')

# Use the data from this link: https://drive.google.com/drive/u/1/folders/1xSE6zhEgj8M-Bs6ZpkycRYCjjELk2Rbl
data = pd.read_csv("/content/scotch.csv")
data = data.drop([u'age', u'dist', u'score', u'percent', u'region', u'district', u'islay', u'midland', u'spey', u'east', u'west', u'north ', u'lowland', u'campbell', u'islands'], axis=1)
data = data.sample(n=53,random_state=42)

# %%
data.head(20)
# Out:
#                color.wyne  color.yellow  color.v.pale  color.pale  \
# Laphroaig               0             0             0           0
# Ben Nevis               0             0             0           0
# Auchentoshan            0             0             0           0
# Macallan                0             0             0           0
# Glenturret              1             0             0           0
# Imperial                0             0             0           0
# Dalmore                 0             0             0           0
# Glenfarclas             0             0             0           0
# Speyburn                0             0             0           0
# Benriach                0             0             0           0
# Linkwood                0             0             0           0
# Littlemill              1             0             0           0
# Aberfeldy               0             1             0           0
# ...

# %% [markdown]
# ### Question 1) How many rows are there in the scotch data?
#
# a) 53 \
# b) 96 \
# c) 109 \
# d) 123

# %%
# Answer 1

# %% [markdown]
# ### Question 2) What is the nearest Whiskey from Tormore according to the Eucleadian distance?
#
# Hint: Use the whiskey_disctance function from the notebook.
#
# a) Glenrothes \
# b) Glen Ordie \
# c) Glencadam \
# d) Imperial

# %%
def whiskey_distance(name, distance_measures, n):
    distances = pd.DataFrame()
    whiskey_location = np.where(data.index == name)[0][0]
    for distance_measure in distance_measures:
        current_distances = distance.squareform(distance.pdist(data, distance_measure))
        most_similar = np.argsort(current_distances[:, whiskey_location])[0:n]
        distances[distance_measure] = list(zip(data.index[most_similar], current_distances[most_similar, whiskey_location]))
    return distances

# %%
# Answer 2
# Hint: Use the whiskey_distance function to find the result

# %% [markdown]
# ### Question 3) Train a Kmeans model with 5 clusters. In which cluster does Glenturret belongs to according to this model?
#
# Hint: Check the Kmeans() model with 5 clusters.
# a) 1\
# b) 2\
# c) 3\
# d) 4\

# %%
from sklearn.cluster import KMeans
k_clusters = 5
# Train the KMeans model with 5 clusters
np.random.seed(42)
model =
model.fit(data)
# Keep the prediction in this variable
clusters =
df = pd.DataFrame(list(zip(data.index,clusters)), columns=['Whiskey','Cluster_predicted'])
print(df[df["Whiskey"] == 'Glenturret'].to_string(index=False))

# %%
from sklearn.datasets import make_blobs
def make_cluster_data():
    np.random.seed(46)
    X, Y = make_blobs(n_samples=10000, n_features=2, centers=3, cluster_std=1.5)
    return X, Y
X,Y = make_cluster_data()

# %% [markdown]
# ### Question 4: What is the accuracy for this data with KNeighboursClassifier with 5 n_neighbours?
#
# a) .8921 \
# b) .9184 \
# c) .9231 \
# d) .9342

# %%
#Answer 4
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=.75,random_state=42)
# Train a KNeighborsClassifier here
model =
model.fit(X_train, Y_train)
# Store the prediction result in y_pred variable
y_pred =
metrics.accuracy_score(Y_test, y_pred)

# %% [markdown]
# ### Question 5: What is the auc score for label 2?
#
# a) .923 \
# b) .962 \
# c) .932 \
# d) .948

# %%
#Answer 5
# Store the probabilities of the model in this variable
probabilities =
auc = metrics.roc_auc_score(Y_test == 2, probabilities[:,2])
print(auc)
